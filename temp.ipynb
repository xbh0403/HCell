# %%
import joblib

results = joblib.load('./results_popv/results_popv.pickle')

# %%
df_list = []
dict_list = []
for i in range(len(results)):
    df_list.append(results[i][0])
    dict_list.append(results[i][1])

# %%
import pandas as pd
results_df = pd.concat(df_list)

# %%
results_df.to_csv('./results_popv/results_popv.csv')

# %%
# Concat dict list into one dict
results_dict = {}
for d in dict_list:
    for k, v in d.items():
        results_dict[k] = v

# %%
import pickle
with open('./results_popv/results_popv_dict.pickle', 'wb') as handle:
    pickle.dump(results_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
results_df
# Out:
#   fold                model  accuracy        f1    recall         time  \
# 0    0   Proto_Net+disto_pl  0.872004  0.870575  0.872004   364.958972
# 0    0      Proto_Net+disto  0.870606  0.869057  0.870606   332.015761
# 0    0         Proto_Net+pl  0.870965  0.868787  0.870965  1831.945116
# 0    0            Proto_Net  0.872457  0.871798  0.872457  2107.263618
# 0    0                  Net  0.872438  0.870935  0.872438   360.001313
# 0    0  Logistic Regression  0.824949  0.822573  0.824949  2470.786714
# 0    0                  KNN  0.861029  0.858677  0.861029      0.13397
# 0    1   Proto_Net+disto_pl  0.871021  0.869662  0.871021   356.221278
# 0    1      Proto_Net+disto  0.870398  0.870115  0.870398   328.780854
# 0    1         Proto_Net+pl  0.872665  0.871008  0.872665  2126.881185
# 0    1            Proto_Net  0.869661  0.867955  0.869661  2103.710191
# 0    1                  Net  0.872023  0.870526  0.872023   359.571263
# 0    1  Logistic Regression  0.826007  0.822977  0.826007  2173.056454
# 0    1                  KNN  0.857685  0.855314  0.857685     0.131697
# 0    2   Proto_Net+disto_pl  0.871758  0.870246  0.871758   402.501229
# 0    2      Proto_Net+disto  0.870379  0.868727  0.870379   973.468605
# 0    2         Proto_Net+pl  0.873949  0.872007  0.873949  2771.549633
# 0    2            Proto_Net  0.873571  0.872232  0.873571  2450.973636
# 0    2                  Net  0.872457   0.87141  0.872457    364.47634
# 0    2  Logistic Regression  0.825535  0.822648  0.825535   682.153085
# 0    2                  KNN  0.859952  0.857009  0.859952     0.133094
# 0    3   Proto_Net+disto_pl  0.872816  0.871068  0.872816   352.177662
# 0    3      Proto_Net+disto  0.872514  0.871099  0.872514   928.978779
# 0    3         Proto_Net+pl  0.871853  0.870221  0.871853  2428.363914
# 0    3            Proto_Net  0.873855  0.871943  0.873855  1810.041731
# 0    3                  Net  0.870266  0.868272  0.870266   659.405115
# 0    3  Logistic Regression  0.824779  0.821695  0.824779  1277.814342
# 0    3                  KNN  0.859725  0.857193  0.859725     0.131546
# 0    4   Proto_Net+disto_pl  0.870417  0.869025  0.870417   351.663343
# 0    4      Proto_Net+disto  0.869416  0.868992  0.869416   927.501142
# 0    4         Proto_Net+pl  0.870001  0.868565  0.870001  2425.724812
# 0    4            Proto_Net  0.873666  0.871835  0.873666  2106.946748
# 0    4                  Net  0.872721    0.8715  0.872721   360.067146
# 0    4  Logistic Regression  0.824024  0.821187  0.824024  1280.778541
# 0    4                  KNN  0.858592  0.856325  0.858592     0.130852
#
#   training_error testing_error
# 0      11.492408     12.799637
# 0      11.398487     12.939421
# 0      11.297958      12.90353
# 0      11.225275     12.754302
# 0       11.41595     12.756191
# 0      16.853487     17.505053
# 0       0.097612      0.138971
# 0      11.228579     12.897864
# 0      11.182326     12.960199
# 0      11.027048     12.733523
# 0      11.196485     13.033869
# 0      11.314949     12.797748
# 0      16.775141     17.399271
# 0       0.097995      0.142315
# 0      11.470226     12.824194
# 0      11.398487     12.962088
# 0      11.208756     12.605074
# 0      11.246985     12.642853
# 0      11.347986     12.754302
# 0      16.884165     17.446495
# 0       0.097329      0.140048
# 0      11.507511     12.718412
# 0      11.294182     12.748635
# 0      11.292766     12.814749
# 0      11.049231     12.614519
# 0       11.55754     12.973422
# 0      16.771837     17.522054
# 0       0.098655      0.140275
# 0       11.44002     12.958311
# 0      11.453235     13.058426
# 0      11.347514     12.999868
# 0      11.137017     12.633408
# 0      11.425861     12.727857
# 0      16.715673     17.597612
# 0       0.097192      0.141408

# %%
temp = pd.read_csv('dist_data.csv')

# %%
temp
# Out:
#      Unnamed: 0  ABCs  Alveolar macrophages  Classical monocytes  Cycling  \
# 0             0     0                     5                    5        4
# 1             1     5                     0                    4        3
# 2             2     5                     4                    0        3
# 3             3     4                     3                    3        0
# 4             4     4                     5                    5        4
# ..          ...   ...                   ...                  ...      ...
# 180         180     6                     7                    7        6
# 181         181     5                     6                    6        5
# 182         182     5                     6                    6        5
# 183         183     6                     7                    7        6
# 184         184     5                     4                    4        3
#
#      Cycling T&NK  DC1  DC2  Erythrophagocytic macrophages  GC_B (I)  ...  \
# 0               4    5    5                              5         3  ...
# 1               5    4    4                              2         6  ...
# 2               5    4    4                              4         6  ...
# 3               4    3    3                              3         5  ...
# 4               0    5    5                              5         5  ...
# ..            ...  ...  ...                            ...       ...  ...
# 180             4    7    7                              7         7  ...
# 181             3    6    6                              6         6  ...
# 182             3    6    6                              6         6  ...
# 183             4    7    7                              7         7  ...
# 184             5    2    2                              4         6  ...
#
#      Tgd_CRTAM+  Tnaive/CM_CD4  Tnaive/CM_CD4_activated  Tnaive/CM_CD8  Tregs  \
# 0             5              6                        6              5      5
# 1             6              7                        7              6      6
# 2             6              7                        7              6      6
# 3             5              6                        6              5      5
# 4             3              4                        4              3      3
# ..          ...            ...                      ...            ...    ...
# 180           3              6                        6              3      5
# 181           2              5                        5              2      4
# 182           4              3                        3              4      2
# 183           3              6                        6              3      5
# 184           6              7                        7              6      6
#
#      Trm/em_CD8  Trm_Tgd  Trm_Th1/Th17  Trm_gut_CD8  migDC
# 0             6        5             5            6      5
# 1             7        6             6            7      4
# 2             7        6             6            7      4
# 3             6        5             5            6      3
# 4             4        3             3            4      5
# ..          ...      ...           ...          ...    ...
# 180           0        3             5            2      7
# 181           3        0             4            3      6
# 182           5        4             0            5      6
# 183           2        3             5            0      7
# 184           7        6             6            7      0
#
# [185 rows x 38 columns]

# %%
import helper_fns
import pandas as pd
import numpy as np
import scanpy as sc
from sklearn.preprocessing import LabelEncoder
import joblib
import ray

dataset_celltypist = sc.read("/Volumes/SSD/global.h5ad")
list_celltypes = dataset_celltypist.obs['Manually_curated_celltype'].unique().tolist()
list_celltypes = list(filter(lambda x: x not in ['Mast cells', 'pDC','Progenitor', 'Erythroid', 'Megakaryocytes'], list_celltypes))
list_filtered_celltypes = list(filter(lambda x: 'doublets' not in x, list_celltypes)) 
dataset_celltypist = dataset_celltypist[dataset_celltypist.obs['Manually_curated_celltype'].isin(list_filtered_celltypes)]

# dataset_celltypist = sc.read("./pre_processed_datasets/celltypist_pca.h5ad")
# dataset_popv = sc.read("./pre_processed_datasets/popv_immune_pca.h5ad")
# list_celltypes = dataset_celltypist.obs['Manually_curated_celltype'].unique().tolist()

encoder_celltype = LabelEncoder()
encoder_celltype.fit(dataset_celltypist.obs['Manually_curated_celltype'])

list_ct = dataset_celltypist.obs['Manually_curated_celltype'].unique().tolist()
list_num_ct = encoder_celltype.transform(list_ct)
list_inner_nodes = ['Cross-tissue Immune Cell Atlas', 'B cell', 'Germinal center B cell', 'Myeloid', 'Dendritic cell',
                    'Macrophages', 'Monocytes', 'T & Innate lymphoid cells', 'CD4', 'T Naive', 'CD8', 
                    'Tissue-resident memory T (Trm) cells', 'NK']
all_nodes = list_ct + list_inner_nodes

encoder_celltype_inner = LabelEncoder()
encoder_celltype_inner.fit(list_inner_nodes)

# encoder_celltype_popv = LabelEncoder()
# encoder_celltype_popv.fit(dataset_popv.obs['cell_type'])

graph_celltypist = helper_fns.build_hierarchical_tree_celltypist(all_nodes=all_nodes, list_ct=list_ct, list_inner_nodes=list_inner_nodes, encoder_celltype=encoder_celltype, encoder_celltype_inner=encoder_celltype_inner)
distance_matrix_celltypist = helper_fns.get_dist_df(list_num_ct=list_num_ct, g=graph_celltypist)
celltypes = []
for i in range(len(list_ct)):
    celltype = helper_fns.inverse_transform(distance_matrix_celltypist.index[i], list_ct=list_ct, encoder_celltype=encoder_celltype, encoder_celltype_inner=encoder_celltype_inner)
    celltypes.append(celltype)
distance_matrix_celltypist.index = celltypes
distance_matrix_celltypist.columns = celltypes

print('Trm_Th1/Th17' in distance_matrix_celltypist.index)
print('Trm_Th1/Th17' in distance_matrix_celltypist.columns)
print(distance_matrix_celltypist.loc['Trm_Th1/Th17', 'Trm_Th1/Th17'])

# load results_dict from results_0908
results_dict = joblib.load('./results_celltypist_cv/results_celltypist_dict.pickle')

celltypes_celltypist = dataset_celltypist.obs['Manually_curated_celltype'].values

all_models = ['KNN', 'Logistic Regression', 'Net', 'Proto_Net', 'Proto_Net+pl', 'Proto_Net+disto', 'Proto_Net+disto_pl']

# load cv
cv = joblib.load('results_celltypist_cv/cv.pkl')

all_keys = results_dict.keys()
keys_fold_0 = [key for key in all_keys if 'fold_0' in key]
keys_fold_1 = [key for key in all_keys if 'fold_1' in key]
keys_fold_2 = [key for key in all_keys if 'fold_2' in key]
keys_fold_3 = [key for key in all_keys if 'fold_3' in key]
keys_fold_4 = [key for key in all_keys if 'fold_4' in key]

true_labels_fold_0 = celltypes_celltypist[cv[0]['test']]
true_labels_fold_1 = celltypes_celltypist[cv[1]['test']]
true_labels_fold_2 = celltypes_celltypist[cv[2]['test']]
true_labels_fold_3 = celltypes_celltypist[cv[3]['test']]
true_labels_fold_4 = celltypes_celltypist[cv[4]['test']]

# ray.init()

@ray.remote
def get_distance_matrix_celltypist(true_labels, keys_fold, fold_str, fold_num, distance_matrix_celltypist):
    df_dist = pd.DataFrame(columns=['model', 'fold', 'distance'])
    print(fold_str)
    total = len(keys_fold)
    for key in keys_fold:
        pred_labels = results_dict[key]
        for i in range(len(pred_labels)):
            dist = distance_matrix_celltypist.loc[true_labels[i], pred_labels[i]]
            df_dist = pd.concat([df_dist, pd.DataFrame([[key[0].split(fold_str)[0], fold_num , dist]], columns=['model', 'fold', 'distance'])], ignore_index=True)
            if i == 2:
                break
    print(df_dist)
    return df_dist


cv0 = get_distance_matrix_celltypist.remote(true_labels_fold_0, keys_fold_0, 'fold_0', 0, distance_matrix_celltypist)
cv1 = get_distance_matrix_celltypist.remote(true_labels_fold_1, keys_fold_1, 'fold_1', 1, distance_matrix_celltypist)
cv2 = get_distance_matrix_celltypist.remote(true_labels_fold_2, keys_fold_2, 'fold_2', 2, distance_matrix_celltypist)
cv3 = get_distance_matrix_celltypist.remote(true_labels_fold_3, keys_fold_3, 'fold_3', 3, distance_matrix_celltypist)
cv4 = get_distance_matrix_celltypist.remote(true_labels_fold_4, keys_fold_4, 'fold_4', 4, distance_matrix_celltypist)

results_cv0, results_cv1, results_cv2, results_cv3, results_cv4 = ray.get([cv0, cv1, cv2, cv3, cv4])

results_cv = pd.concat([results_cv0, results_cv1, results_cv2, results_cv3, results_cv4])

# results_cv.to_csv('dist_data.csv')
# Out:
# True
# True
# 0
# (get_distance_matrix_celltypist pid=57108) fold_0
# (get_distance_matrix_celltypist pid=57108)    model fold distance
# (get_distance_matrix_celltypist pid=57108) 0      p    0        0
# (get_distance_matrix_celltypist pid=57108) 1      p    0        0
# (get_distance_matrix_celltypist pid=57108) 2      p    0        0
# (get_distance_matrix_celltypist pid=57108) 3      p    0        0
# (get_distance_matrix_celltypist pid=57108) 4      p    0        0
# (get_distance_matrix_celltypist pid=57108) 5      p    0        0
# (get_distance_matrix_celltypist pid=57108) 6      p    0        0
# (get_distance_matrix_celltypist pid=57108) 7      p    0        0
# (get_distance_matrix_celltypist pid=57108) 8      p    0        0
# (get_distance_matrix_celltypist pid=57108) 9      p    0        0
# (get_distance_matrix_celltypist pid=57108) 10     p    0        0
# (get_distance_matrix_celltypist pid=57108) 11     p    0        0
# (get_distance_matrix_celltypist pid=57108) 12     N    0        0
# (get_distance_matrix_celltypist pid=57108) 13     N    0        0
# (get_distance_matrix_celltypist pid=57108) 14     N    0        0
# (get_distance_matrix_celltypist pid=57108) 15     l    0        0
# (get_distance_matrix_celltypist pid=57108) 16     l    0        0
# (get_distance_matrix_celltypist pid=57108) 17     l    0        0
# (get_distance_matrix_celltypist pid=57108) 18     k    0        5
# (get_distance_matrix_celltypist pid=57108) 19     k    0        0
# (get_distance_matrix_celltypist pid=57108) 20     k    0        0
# (get_distance_matrix_celltypist pid=57101) fold_2
# (get_distance_matrix_celltypist pid=57101)    model fold distance
# (get_distance_matrix_celltypist pid=57101) 0      p    2        0
# (get_distance_matrix_celltypist pid=57101) 1      p    2        3
# (get_distance_matrix_celltypist pid=57101) 2      p    2        0
# (get_distance_matrix_celltypist pid=57101) 3      p    2        0
# (get_distance_matrix_celltypist pid=57101) 4      p    2        3
# (get_distance_matrix_celltypist pid=57101) 5      p    2        0
# (get_distance_matrix_celltypist pid=57101) 6      p    2        0
# (get_distance_matrix_celltypist pid=57101) 7      p    2        3
# (get_distance_matrix_celltypist pid=57101) 8      p    2        0
# (get_distance_matrix_celltypist pid=57101) 9      p    2        0
# (get_distance_matrix_celltypist pid=57101) 10     p    2        3
# (get_distance_matrix_celltypist pid=57101) 11     p    2        0
# (get_distance_matrix_celltypist pid=57101) 12     N    2        0
# (get_distance_matrix_celltypist pid=57101) 13     N    2        3
# (get_distance_matrix_celltypist pid=57101) 14     N    2        0
# (get_distance_matrix_celltypist pid=57101) 15     l    2        0
# (get_distance_matrix_celltypist pid=57101) 16     l    2        3
# (get_distance_matrix_celltypist pid=57101) 17     l    2        0
# (get_distance_matrix_celltypist pid=57101) 18     k    2        0
# (get_distance_matrix_celltypist pid=57101) 19     k    2        3
# (get_distance_matrix_celltypist pid=57101) 20     k    2        4
# (get_distance_matrix_celltypist pid=57106) fold_4
# (get_distance_matrix_celltypist pid=57106)    model fold distance
# (get_distance_matrix_celltypist pid=57106) 0      p    4        0
# (get_distance_matrix_celltypist pid=57106) 1      p    4        0
# (get_distance_matrix_celltypist pid=57106) 2      p    4        0
# (get_distance_matrix_celltypist pid=57106) 3      p    4        0
# (get_distance_matrix_celltypist pid=57106) 4      p    4        0
# (get_distance_matrix_celltypist pid=57106) 5      p    4        0
# (get_distance_matrix_celltypist pid=57106) 6      p    4        0
# (get_distance_matrix_celltypist pid=57106) 7      p    4        0
# (get_distance_matrix_celltypist pid=57106) 8      p    4        0
# (get_distance_matrix_celltypist pid=57106) 9      p    4        0
# (get_distance_matrix_celltypist pid=57106) 10     p    4        0
# (get_distance_matrix_celltypist pid=57106) 11     p    4        0
# (get_distance_matrix_celltypist pid=57106) 12     N    4        0
# (get_distance_matrix_celltypist pid=57106) 13     N    4        0
# (get_distance_matrix_celltypist pid=57106) 14     N    4        0
# (get_distance_matrix_celltypist pid=57106) 15     l    4        0
# (get_distance_matrix_celltypist pid=57106) 16     l    4        0
# (get_distance_matrix_celltypist pid=57106) 17     l    4        0
# (get_distance_matrix_celltypist pid=57106) 18     k    4        0
# (get_distance_matrix_celltypist pid=57106) 19     k    4        0
# (get_distance_matrix_celltypist pid=57106) 20     k    4        0
# (get_distance_matrix_celltypist pid=57107) fold_3
# (get_distance_matrix_celltypist pid=57107)    model fold distance
# (get_distance_matrix_celltypist pid=57107) 0      p    3        0
# (get_distance_matrix_celltypist pid=57107) 1      p    3        0
# (get_distance_matrix_celltypist pid=57107) 2      p    3        0
# (get_distance_matrix_celltypist pid=57107) 3      p    3        0
# (get_distance_matrix_celltypist pid=57107) 4      p    3        0
# (get_distance_matrix_celltypist pid=57107) 5      p    3        0
# (get_distance_matrix_celltypist pid=57107) 6      p    3        0
# (get_distance_matrix_celltypist pid=57107) 7      p    3        0
# (get_distance_matrix_celltypist pid=57107) 8      p    3        0
# (get_distance_matrix_celltypist pid=57107) 9      p    3        0
# (get_distance_matrix_celltypist pid=57107) 10     p    3        0
# (get_distance_matrix_celltypist pid=57107) 11     p    3        0
# (get_distance_matrix_celltypist pid=57107) 12     N    3        0
# (get_distance_matrix_celltypist pid=57107) 13     N    3        0
# (get_distance_matrix_celltypist pid=57107) 14     N    3        0
# (get_distance_matrix_celltypist pid=57107) 15     l    3        0
# (get_distance_matrix_celltypist pid=57107) 16     l    3        0
# (get_distance_matrix_celltypist pid=57107) 17     l    3        0
# (get_distance_matrix_celltypist pid=57107) 18     k    3        0
# (get_distance_matrix_celltypist pid=57107) 19     k    3        0
# (get_distance_matrix_celltypist pid=57107) 20     k    3        0
# (get_distance_matrix_celltypist pid=57105) fold_1
# (get_distance_matrix_celltypist pid=57105)    model fold distance
# (get_distance_matrix_celltypist pid=57105) 0      p    1        0
# (get_distance_matrix_celltypist pid=57105) 1      p    1        5
# (get_distance_matrix_celltypist pid=57105) 2      p    1        0
# (get_distance_matrix_celltypist pid=57105) 3      p    1        0
# (get_distance_matrix_celltypist pid=57105) 4      p    1        5
# (get_distance_matrix_celltypist pid=57105) 5      p    1        0
# (get_distance_matrix_celltypist pid=57105) 6      p    1        0
# (get_distance_matrix_celltypist pid=57105) 7      p    1        5
# (get_distance_matrix_celltypist pid=57105) 8      p    1        0
# (get_distance_matrix_celltypist pid=57105) 9      p    1        0
# (get_distance_matrix_celltypist pid=57105) 10     p    1        5
# (get_distance_matrix_celltypist pid=57105) 11     p    1        0
# (get_distance_matrix_celltypist pid=57105) 12     N    1        0
# (get_distance_matrix_celltypist pid=57105) 13     N    1        5
# (get_distance_matrix_celltypist pid=57105) 14     N    1        0
# (get_distance_matrix_celltypist pid=57105) 15     l    1        0
# (get_distance_matrix_celltypist pid=57105) 16     l    1        5
# (get_distance_matrix_celltypist pid=57105) 17     l    1        0
# (get_distance_matrix_celltypist pid=57105) 18     k    1        0
# (get_distance_matrix_celltypist pid=57105) 19     k    1        0
# (get_distance_matrix_celltypist pid=57105) 20     k    1        0

# %%
results_cv
# Out:
#    model fold distance
# 0      p    0        0
# 1      p    0        0
# 2      p    0        0
# 3      p    0        0
# 4      p    0        0
# ..   ...  ...      ...
# 16     l    4        0
# 17     l    4        0
# 18     k    4        0
# 19     k    4        0
# 20     k    4        0
#
# [105 rows x 3 columns]

# %%
import pandas as pd

temp = pd.read_csv('./results_celltypist_cv/dist_df_celltypist.csv')
